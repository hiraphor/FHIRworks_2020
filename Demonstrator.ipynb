# %%
import pandas as pd
import seaborn as sns
from SyntheticDataGenerator import SyntheticDataGenerator as sdg
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
datagen = sdg()

patient_data = datagen.createObservations()

syntheticdata = datagen.generateSyntheticData(1000)

# %%
syntheticdata
# Out:
#       birthsex_is_male  disabilityAdjLifeYears  QualAdjLifeYears  \
# 0                    0                       2                42
# 1                    1                       3                68
# 2                    0                      33                21
# 3                    1                      11                57
# 4                    0                       7                71
# ...                ...                     ...               ...
# 1506                 0                       0                63
# 1509                 0                      18                56
# 1510                 1                       2                 5
# 1511                 1                       1                88
# 1512                 0                      15                40
#
#       Alanine aminotransferase [Enzymatic activity/volume] in Serum or Plasma  \
# 0                                                    41
# ...

# %%
sns.scatterplot(x=syntheticdata["Body Weight"], y=syntheticdata["Heart rate"])

# %%
sns.scatterplot(x=patient_data["Body Weight"], y=patient_data["Heart rate"])

# %%
sns.scatterplot(x=syntheticdata["Body Height"], y=syntheticdata["Body Weight"])

# %%
sns.scatterplot(x=patient_data["Body Height"], y=patient_data["Body Weight"])
